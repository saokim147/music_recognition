# %%
# !git clone https://github.com/saokim147/music_recognition.git
# Out:
# Cloning into 'music_recognition'...
# remote: Enumerating objects: 4337, done.
# remote: Total 4337 (delta 0), reused 0 (delta 0), pack-reused 4337 (from 1)
# Receiving objects: 100% (4337/4337), 719.34 MiB | 13.79 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Updating files: 100% (4331/4331), done.

# %%
! pip install numpy librosa torch

# %%
! pip install --upgrade librosa

# %%
! pip show torchaudio
# Out:
# Name: torchaudio
# Version: 2.8.0
# Summary: An audio package for PyTorch
# Home-page: https://github.com/pytorch/audio
# Author: Soumith Chintala, David Pollack, Sean Naren, Peter Goldsborough, Moto Hira, Caroline Chen, Jeff Hwang, Zhaoheng Ni, Xiaohui Zhang
# Author-email: soumith@pytorch.org
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: torch
# Required-by: wavaugment

# %%
! pip install torchaudio==2.8.0 torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 133.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.9/887.9 MB 1.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 128.4 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 29.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 13.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 38.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 4.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 2.9 MB/s eta 0:00:00:00:0100:01
# ...

# %%
! pip install torch torchvision WavAugment

# %%
import os
os.makedirs('/content/music_recognition/temp_dir', exist_ok=True)

# %%
# !cp -r /content/music_recognition/CHAD/*  /content/music_recognition/temp_dir/

# %%
# !python3 '/content/music_recognition/preprocessing.py' --config '/content/music_recognition/config/preprocess.yaml'
# Out:
# Processed 84 lines.
# 100% 83/83 [00:17<00:00,  4.87it/s]
# 100% 29/29 [00:49<00:00,  1.72s/it]
# Processing train
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 48 out of 83 | elapsed:    5.9s
# [Parallel(n_jobs=4)]: Done 83 out of 83 | elapsed:    6.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 29 out of 29 | elapsed:    0.5s finished

# %%
# !find /content/music_recognition/preprocessed -name "*.npy" | head -10 && echo "---" && find  /content/music_recognition/preprocessed -name "*.npy"

# %%
! python3 '/content/music_recognition/utils/split_train_val_by_id.py' --config '/content/music_recognition/config/preprocess.yaml' --val_size 5
# Out:
# Processed 84 lines.
# Not found: song=77cc250bd0dc4c2b_1_e3f6609557e7287d.npy or hum=hum_77cc250bd0dc4c2b_1_eda3924de4edc9e4.npy
# Not found: song=26803c35992f8280_2_a6308fdcd5fea8c0.npy or hum=hum_26803c35992f8280_2_49704b645bbef4cd.npy
# Not found: song=26803c35992f8280_2_a6308fdcd5fea8c0.npy or hum=hum_26803c35992f8280_2_7760d7a7bc992105.npy
# Not found: song=26803c35992f8280_2_a6308fdcd5fea8c0.npy or hum=hum_26803c35992f8280_2_89a39b8e7aaf9408.npy
# Not found: song=26803c35992f8280_2_a6308fdcd5fea8c0.npy or hum=hum_26803c35992f8280_2_cd8ac5d27b18a885.npy
# Not found: song=0bc7f9ae9b644f29_2_0d7893612d6572a1.npy or hum=hum_0bc7f9ae9b644f29_2_eb8d63b9daca0a10.npy
# Not found: song=15c760a6bdb3d6f2_1_6d07d306c4c61dd8.npy or hum=hum_15c760a6bdb3d6f2_1_fafea16f955c5ba9.npy
# Count: 5 files

# %%
# !sudo apt-get update && sudo apt-get install -y sox libsox-fmt-all
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,160 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,066 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
! ls 'content/music_recognition'
# Out:
# ls: cannot access 'content/music_recognition': No such file or directory

# %%
! python3 '/content/music_recognition/utils/augment_mp3.py'
# Out:
# /usr/local/lib/python3.12/dist-packages/augment/effects.py:291: UserWarning: torchaudio.sox_effects.sox_effects.effect_names has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   for _effect_name in get_effect_names():
# /usr/local/lib/python3.12/dist-packages/torchaudio/sox_effects/sox_effects.py:53: UserWarning: torchaudio.utils.sox_utils.list_effects has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   return list(list_effects().keys())
# Traceback (most recent call last):
#   File "/content/music_recognition/utils/augment_mp3.py", line 1, in <module>
#     import augment
# ...
